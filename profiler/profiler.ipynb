# %% [markdown]
# # Is a good portion of an ML execution spent in C code?

# %%
import pstats
import io
import pandas as pd
import numpy as np

import os
import re
import importlib

# The module below implements a function that identifies which modules are C Extensions
import c_extens # thanks https://stackoverflow.com/questions/20339053/in-python-how-can-one-tell-if-a-module-comes-from-a-c-extension

# %% [markdown]
# # The function below turns the binary output of cProfile into a string
# We acquire the binary output of [cProfile](https://docs.python.org/3.7/library/profile.html#module-cProfile) by running:
#
# `python -m cProfile -o output.cprof code_i_want_to_profile.py`

# %%
def get_raw_output(source):
    stream = io.StringIO()
    stats = pstats.Stats(source, stream=stream)
    stats.print_stats()
    raw_output = stream.getvalue().split('\n')
    stream.close()
    return raw_output

# %% [markdown]
# # The function below turns the string output of cProfile into a pandas DF

# %%
def to_df(raw: str) -> pd.DataFrame:
    columns = ['ncalls', 'tottime', 'percall', 'cumtime', 'percall', 'filename:lineno(function)']
    
    # filter non-tabular metadata
    tabular_raw = None
    for i, line in enumerate(raw):
        if line.split() == columns:
            tabular_raw = raw[i:]
            break
    
    # we unique the names of the columns for Pandas
    columns[2] = 'percallnode'
    columns[4] = 'percallgraph'
    
    # we rename for pandas
    columns[5] = 'plf' # p: path, l: lineno, f: function
    
    import re
    tabular = [re.split('\s\s+', line) for line in tabular_raw[1:]]
    
    # preprocess
    for i in range(len(tabular)):
        # filter empty cells
        line = tabular.pop(0)
        line = [word for word in line if word]
        if line:
            # Last cell needs to be unmerged
            last = line.pop()
            split_idx = last.find(' ')
            n, s = last[0:split_idx], last[split_idx+1:]
            line.append(n)
            line.append(s)
            assert len(line) == len(columns), "i: {}, len: {} --- {}".format(i, len(line), line)
            tabular.append(line)
    
    # Ready to load into DF
    df = pd.DataFrame(tabular)
    df.columns = columns
    return df

# %% [markdown]
# # Load the cProfile binary into a pandas DataFrame

# %%
df = to_df(get_raw_output('basic.cprof'))

# %%
df
# Out:
#      ncalls tottime percallnode cumtime percallgraph  \
# 0       825   0.000       0.000   0.000        0.000
# 1        58   0.000       0.000   0.000        0.000
# 2        13   0.000       0.000   0.000        0.000
# 3         2   0.000       0.000   0.000        0.000
# 4         1   0.000       0.000   0.000        0.000
# 5         1   0.000       0.000   0.000        0.000
# 6         7   0.000       0.000   0.000        0.000
# 7       430   0.000       0.000   0.000        0.000
# 8       616   0.000       0.000   0.000        0.000
# 9        96   0.000       0.000   0.000        0.000
# 10        3   0.000       0.000   0.000        0.000
# 11       70   0.000       0.000   0.000        0.000
# 12        2   0.000       0.000   0.000        0.000
# 13    28964   0.003       0.000   0.003        0.000
# 14       58   0.000       0.000   0.000        0.000
# 15      431   0.000       0.000   0.000        0.000
# 16      253   0.000       0.000   0.000        0.000
# 17       13   0.000       0.000   0.000        0.000
# 18       14   0.000       0.000   0.000        0.000
# 19       39   0.000       0.000   0.000        0.000
# 20       31   0.000       0.000   0.000        0.000
# 21       18   0.000       0.000   0.000        0.000
# 22     1425   0.001       0.000   0.001        0.000
# 23      384   0.000       0.000   0.000        0.000
# 24     6086   0.001       0.000   0.001        0.000
# 25      175   0.000       0.000   0.000        0.000
# 26      379   0.000       0.000   0.000        0.000
# 27       66   0.000       0.000   0.000        0.000
# 28      837   0.000       0.000   0.000        0.000
# 29       20   0.000       0.000   0.000        0.000
# ...     ...     ...         ...     ...          ...
# 3539      2   0.001       0.000   0.001        0.000
# 3540      1   0.000       0.000   0.000        0.000
# 3541      1   0.000       0.000   0.000        0.000
# 3542      1   0.000       0.000   0.000        0.000
# 3543      1   0.000       0.000   0.000        0.000
# 3544      1   0.000       0.000   0.000        0.000
# 3545      1   0.000       0.000   0.000        0.000
# 3546      1   0.000       0.000   0.000        0.000
# 3547      1   0.000       0.000   0.000        0.000
# 3548      1   0.000       0.000   0.000        0.000
# 3549      1   0.000       0.000   0.000        0.000
# 3550      1   0.000       0.000   0.000        0.000
# 3551    120   0.000       0.000   0.000        0.000
# 3552      1   0.002       0.002   0.025        0.025
# 3553      1   0.000       0.000   0.000        0.000
# 3554    522   0.000       0.000   0.000        0.000
# 3555      1   0.000       0.000   0.000        0.000
# 3556      4   0.000       0.000   0.000        0.000
# 3557      4   0.000       0.000   0.000        0.000
# 3558      1   0.000       0.000   0.000        0.000
# 3559     62   0.000       0.000   0.000        0.000
# 3560     12   0.000       0.000   0.000        0.000
# 3561    124   0.000       0.000   0.000        0.000
# 3562    120   0.001       0.000   0.001        0.000
# 3563    118   0.000       0.000   0.000        0.000
# 3564     60   0.000       0.000   0.000        0.000
# 3565     60   0.000       0.000   0.000        0.000
# 3566      2   0.000       0.000   0.000        0.000
# 3567    118   0.000       0.000   0.000        0.000
# 3568      2   0.000       0.000   0.000        0.000
#
#                                                     plf
# 0                {method 'find' of 'bytearray' objects}
# 1           {method 'translate' of 'bytearray' objects}
# 2                  {method 'decode' of 'bytes' objects}
# 3                           {built-in method maketrans}
# 4                   {method 'rfind' of 'bytes' objects}
# 5                  {method 'rstrip' of 'bytes' objects}
# 6              {method 'startswith' of 'bytes' objects}
# 7              {method 'get' of 'mappingproxy' objects}
# 8           {method 'values' of 'mappingproxy' objects}
# 9            {method 'items' of 'mappingproxy' objects}
# 10            {method 'copy' of 'mappingproxy' objects}
# 11              {method 'setter' of 'property' objects}
# 12             {method 'deleter' of 'property' objects}
# 13                  {method 'append' of 'list' objects}
# 14                  {method 'insert' of 'list' objects}
# 15                  {method 'extend' of 'list' objects}
# 16                     {method 'pop' of 'list' objects}
# 17                  {method 'remove' of 'list' objects}
# 18                   {method 'index' of 'list' objects}
# 19                 {method 'reverse' of 'list' objects}
# 20                    {method 'sort' of 'list' objects}
# 21               {method 'bit_length' of 'int' objects}
# 22                         {built-in method from_bytes}
# 23       {function RcParams.__getitem__ at 0x11c48f6a8}
# 24                     {method 'get' of 'dict' objects}
# 25              {method 'setdefault' of 'dict' objects}
# 26                     {method 'pop' of 'dict' objects}
# 27                    {method 'keys' of 'dict' objects}
# 28                   {method 'items' of 'dict' objects}
# 29                  {method 'values' of 'dict' objects}
# ...                                                 ...
# 3539                                         {instance}
# 3540            {built-in method PyQt5.QtCore.pyqtSlot}
# 3541                            {built-in method _deco}
# 3542  /anaconda3/lib/python3.7/site-packages/matplot...
# 3543  /anaconda3/lib/python3.7/site-packages/matplot...
# 3544  /anaconda3/lib/python3.7/site-packages/matplot...
# 3545  /anaconda3/lib/python3.7/site-packages/matplot...
# 3546  /anaconda3/lib/python3.7/site-packages/matplot...
# 3547  /anaconda3/lib/python3.7/site-packages/matplot...
# 3548  /anaconda3/lib/python3.7/site-packages/matplot...
# 3549               {built-in method torch._C._jit_init}
# 3550  {built-in method torch._C._tracer_warn_use_pyt...
# 3551      {built-in method torch._C._get_tracing_state}
# 3552          {built-in method torch._C._initExtension}
# 3553          {built-in method torch._C._autograd_init}
# 3554             {built-in method torch._C._add_docstr}
# 3555             {built-in method torch._C._init_names}
# 3556        {built-in method torch._C.set_grad_enabled}
# 3557         {built-in method torch._C.is_grad_enabled}
# 3558   {built-in method torch._C._multiprocessing_init}
# 3559   {method 'dim' of 'torch._C._TensorBase' objects}
# 3560  {method 'item' of 'torch._C._TensorBase' objects}
# 3561  {method 'size' of 'torch._C._TensorBase' objects}
# 3562  {method 'add_' of 'torch._C._TensorBase' objects}
# 3563  {method 'detach_' of 'torch._C._TensorBase' ob...
# 3564  {method 'numel' of 'torch._C._TensorBase' obje...
# 3565     {method 't' of 'torch._C._TensorBase' objects}
# 3566  {method 'uniform_' of 'torch._C._TensorBase' o...
# 3567  {method 'zero_' of 'torch._C._TensorBase' obje...
# 3568                   {built-in method _make_subclass}
#
# [3569 rows x 6 columns]

# %% [markdown]
# # Now I need to preprocess the plf column to extract the relevant modules from the text
#
# Do you see text like `{built-in method torch._C._get_tracing_state}`? I can't use that. I need to transform it so I extract the module name and function name from such strings. The template class below is like a cookie cutter. You press it down on a string and the remainder is the module name and function name (two-tuple).

# %%
class Template:
    
    def __init__(self):
        self.special = {
            "\{method '.*' of '.*' objects\}": lambda x: (x.split("'")[3], x.split("'")[1]),
            "\{built-in method .*\}": lambda x: (None, x[1:-1].split()[-1]),
            "\{function (.*)\.(.*) at 0x(\w)*\}": lambda x: (x[1:-1].split()[1].split('.')),
            "<frozen (.*)\.(.*)>:(\d+)\(\w*\)": lambda x: (x.split(':')[0][len('<frozen') + 1:-1], x.split(':')[1].split('(')[1][:-1]),
            "<frozen (.*)\.(.*)>:(\d+)\(<\w*>\)": lambda x: (x.split(':')[0][len('<frozen') + 1:-1], None),
            "\w+\.py:\d+\(\w+\)": lambda x: (None, None),
            "\w+\.py:\d+\(<\w+>\)": lambda x: (None, None),
            "<string>:\d+\(<\w+>\)": lambda x: (None, None),
            "<string>:\d+\(\w+\)": lambda x: (None, None),
            "\{instance\}": lambda x: (None, None)
        }
        
    def match(self, t):
        for k in self.special:
            pattern = re.compile(k)
            if pattern.match(t):
                return k
            
    def is_c_extension(self, t):
        k = self.match(t)
        if k is not None:
            m, f = self.special[k](t) # m: module, f: function
            if m is None:
                return False
            ms = m.split('.')
            for i in range(len(ms)):
                candidate_mod_name = '.'.join(ms[:len(ms)-i])
                try:
                    candidate_mod = importlib.import_module(candidate_mod_name)
                except:
                    continue
                try:
                    ans = c_extens.is_c_extension(candidate_mod) # I am trusting a stackoverflow solution
                    if ans is None:
                        ans = False
                    return ans
                except:
                    return False
        return False
        

toby = Template()

# %% [markdown]
# # We see calls to C Extensions below

# %%
c_df = df[df['plf'].map(toby.is_c_extension)]
c_df
# Out:
#      ncalls tottime percallnode cumtime percallgraph  \
# 349       1   0.000       0.000   0.000        0.000
# 1048     16   0.000       0.000   0.000        0.000
# 1309     60   0.005       0.000   0.005        0.000
# 3559     62   0.000       0.000   0.000        0.000
# 3560     12   0.000       0.000   0.000        0.000
# 3561    124   0.000       0.000   0.000        0.000
# 3562    120   0.001       0.000   0.001        0.000
# 3563    118   0.000       0.000   0.000        0.000
# 3564     60   0.000       0.000   0.000        0.000
# 3565     60   0.000       0.000   0.000        0.000
# 3566      2   0.000       0.000   0.000        0.000
# 3567    118   0.000       0.000   0.000        0.000
#
#                                                     plf
# 349    {method 'disable' of '_lsprof.Profiler' objects}
# 1048  {method 'getrandbits' of '_random.Random' obje...
# 1309  {method 'run_backward' of 'torch._C._EngineBas...
# 3559   {method 'dim' of 'torch._C._TensorBase' objects}
# 3560  {method 'item' of 'torch._C._TensorBase' objects}
# 3561  {method 'size' of 'torch._C._TensorBase' objects}
# 3562  {method 'add_' of 'torch._C._TensorBase' objects}
# 3563  {method 'detach_' of 'torch._C._TensorBase' ob...
# 3564  {method 'numel' of 'torch._C._TensorBase' obje...
# 3565     {method 't' of 'torch._C._TensorBase' objects}
# 3566  {method 'uniform_' of 'torch._C._TensorBase' o...
# 3567  {method 'zero_' of 'torch._C._TensorBase' obje...

# %% [markdown]
# # Approximately what fraction of time was spent in C code?

# %%
"{0:.3%}".format(c_df['cumtime'].map(float).sum() / df['cumtime'].map(float).max())
# Out:
# '0.653%'
