# %% [markdown]
# # Is a good portion of an ML execution spent in C code?

# %%
import pstats
import io
import pandas as pd
import numpy as np

import os
import re
import importlib

# The module below implements a function that identifies which modules are C Extensions
import c_extens # thanks https://stackoverflow.com/questions/20339053/in-python-how-can-one-tell-if-a-module-comes-from-a-c-extension

# %% [markdown]
# # The function below turns the binary output of cProfile into a string
# We acquire the binary output of [cProfile](https://docs.python.org/3.7/library/profile.html#module-cProfile) by running:
#
# `python -m cProfile -o output.cprof code_i_want_to_profile.py`

# %%
def get_raw_output(source):
    stream = io.StringIO()
    stats = pstats.Stats(source, stream=stream)
    stats.print_stats()
    raw_output = stream.getvalue().split('\n')
    stream.close()
    return raw_output

# %% [markdown]
# # The function below turns the string output of cProfile into a pandas DF

# %%
def to_df(raw: str) -> pd.DataFrame:
    columns = ['ncalls', 'tottime', 'percall', 'cumtime', 'percall', 'filename:lineno(function)']
    
    # filter non-tabular metadata
    tabular_raw = None
    for i, line in enumerate(raw):
        if line.split() == columns:
            tabular_raw = raw[i:]
            break
    
    # we unique the names of the columns for Pandas
    columns[2] = 'percallnode'
    columns[4] = 'percallgraph'
    
    # we rename for pandas
    columns[5] = 'plf' # p: path, l: lineno, f: function
    
    import re
    tabular = [re.split('\s\s+', line) for line in tabular_raw[1:]]
    
    # preprocess
    for i in range(len(tabular)):
        # filter empty cells
        line = tabular.pop(0)
        line = [word for word in line if word]
        if line:
            # Last cell needs to be unmerged
            last = line.pop()
            split_idx = last.find(' ')
            n, s = last[0:split_idx], last[split_idx+1:]
            line.append(n)
            line.append(s)
            assert len(line) == len(columns), "i: {}, len: {} --- {}".format(i, len(line), line)
            tabular.append(line)
    
    # Ready to load into DF
    df = pd.DataFrame(tabular)
    df.columns = columns
    return df

# %% [markdown]
# # Load the cProfile binary into a pandas DataFrame

# %%
df = to_df(get_raw_output('neural_net.cprof'))

# %%
df
# Out:
#       ncalls tottime percallnode cumtime percallgraph  \
# 0        881   0.000       0.000   0.000        0.000
# 1         53   0.000       0.000   0.000        0.000
# 2          2   0.000       0.000   0.000        0.000
# 3         13   0.000       0.000   0.000        0.000
# 4          2   0.000       0.000   0.000        0.000
# 5     310000   0.051       0.000   0.051        0.000
# 6          2   0.000       0.000   0.000        0.000
# 7          3   0.000       0.000   0.000        0.000
# 8          1   0.000       0.000   0.000        0.000
# 9          8   0.000       0.000   0.000        0.000
# 10       408   0.000       0.000   0.000        0.000
# 11         1   0.000       0.000   0.000        0.000
# 12        94   0.000       0.000   0.000        0.000
# 13        31   0.000       0.000   0.000        0.000
# 14         2   0.000       0.000   0.000        0.000
# 15    640897   0.103       0.000   0.103        0.000
# 16        34   0.000       0.000   0.000        0.000
# 17       335   0.000       0.000   0.000        0.000
# 18         1   0.000       0.000   0.000        0.000
# 19         8   0.000       0.000   0.000        0.000
# 20         1   0.000       0.000   0.000        0.000
# 21        19   0.000       0.000   0.000        0.000
# 22        14   0.000       0.000   0.000        0.000
# 23      1362   0.000       0.000   0.000        0.000
# 24    312157   0.067       0.000   0.067        0.000
# 25        57   0.000       0.000   0.000        0.000
# 26        73   0.000       0.000   0.000        0.000
# 27        30   0.000       0.000   0.000        0.000
# 28       102   0.000       0.000   0.000        0.000
# 29         1   0.000       0.000   0.000        0.000
# ...      ...     ...         ...     ...          ...
# 2704    6112   0.006       0.000   0.006        0.000
# 2705    6206   0.010       0.000   0.010        0.000
# 2706       5   0.008       0.002   0.008        0.002
# 2707   36000   0.655       0.000   0.655        0.000
# 2708   18000   2.794       0.000   2.794        0.000
# 2709   18000   0.708       0.000   0.708        0.000
# 2710   17994   0.012       0.000   0.012        0.000
# 2711  310000   4.985       0.000   4.985        0.000
# 2712       6   0.000       0.000   0.000        0.000
# 2713    3000   0.076       0.000   0.076        0.000
# 2714   36000   1.269       0.000   1.269        0.000
# 2715    3000   0.004       0.000   0.004        0.000
# 2716       6   0.000       0.000   0.000        0.000
# 2717    3100   0.025       0.000   0.025        0.000
# 2718       4   0.000       0.000   0.000        0.000
# 2719   18000   0.326       0.000   0.326        0.000
# 2720     100   0.001       0.000   0.001        0.000
# 2721    9300   0.064       0.000   0.064        0.000
# 2722  620000   2.007       0.000   2.007        0.000
# 2723       6   0.004       0.001   0.004        0.001
# 2724  310000   1.869       0.000   1.869        0.000
# 2725   17994   0.339       0.000   0.339        0.000
# 2726       6   0.000       0.000   0.000        0.000
# 2727       2   0.033       0.016   0.033        0.016
# 2728  310000   0.519       0.000   0.519        0.000
# 2729       1   0.000       0.000   0.000        0.000
# 2730   21600   0.026       0.000   0.026        0.000
# 2731       1   0.007       0.007   0.007        0.007
# 2732       1   0.000       0.000   0.000        0.000
# 2733       1   0.000       0.000   0.000        0.000
#
#                                                     plf
# 0                {method 'find' of 'bytearray' objects}
# 1           {method 'translate' of 'bytearray' objects}
# 2                   {method 'count' of 'bytes' objects}
# 3                  {method 'decode' of 'bytes' objects}
# 4                    {method 'find' of 'bytes' objects}
# 5                    {method 'join' of 'bytes' objects}
# 6                           {built-in method maketrans}
# 7                   {method 'rfind' of 'bytes' objects}
# 8                  {method 'rstrip' of 'bytes' objects}
# 9              {method 'startswith' of 'bytes' objects}
# 10             {method 'get' of 'mappingproxy' objects}
# 11          {method 'values' of 'mappingproxy' objects}
# 12           {method 'items' of 'mappingproxy' objects}
# 13              {method 'setter' of 'property' objects}
# 14             {method 'deleter' of 'property' objects}
# 15                  {method 'append' of 'list' objects}
# 16                  {method 'insert' of 'list' objects}
# 17                  {method 'extend' of 'list' objects}
# 18                     {method 'pop' of 'list' objects}
# 19                  {method 'remove' of 'list' objects}
# 20                 {method 'reverse' of 'list' objects}
# 21                    {method 'sort' of 'list' objects}
# 22               {method 'bit_length' of 'int' objects}
# 23                         {built-in method from_bytes}
# 24                     {method 'get' of 'dict' objects}
# 25              {method 'setdefault' of 'dict' objects}
# 26                     {method 'pop' of 'dict' objects}
# 27                    {method 'keys' of 'dict' objects}
# 28                   {method 'items' of 'dict' objects}
# 29                  {method 'values' of 'dict' objects}
# ...                                                 ...
# 2704  {method 'size' of 'torch._C._TensorBase' objects}
# 2705    {method 'to' of 'torch._C._TensorBase' objects}
# 2706  {method 'tolist' of 'torch._C._TensorBase' obj...
# 2707  {method 'add_' of 'torch._C._TensorBase' objects}
# 2708  {method 'addcdiv_' of 'torch._C._TensorBase' o...
# 2709  {method 'addcmul_' of 'torch._C._TensorBase' o...
# 2710  {method 'detach_' of 'torch._C._TensorBase' ob...
# 2711   {method 'div' of 'torch._C._TensorBase' objects}
# 2712  {method 'is_floating_point' of 'torch._C._Tens...
# 2713  {method 'log_softmax' of 'torch._C._TensorBase...
# 2714  {method 'mul_' of 'torch._C._TensorBase' objects}
# 2715  {method 'numel' of 'torch._C._TensorBase' obje...
# 2716  {method 'random_' of 'torch._C._TensorBase' ob...
# 2717  {method 'reshape' of 'torch._C._TensorBase' ob...
# 2718  {method 'set_' of 'torch._C._TensorBase' objects}
# 2719  {method 'sqrt' of 'torch._C._TensorBase' objects}
# 2720   {method 'sum' of 'torch._C._TensorBase' objects}
# 2721     {method 't' of 'torch._C._TensorBase' objects}
# 2722  {method 'transpose' of 'torch._C._TensorBase' ...
# 2723  {method 'uniform_' of 'torch._C._TensorBase' o...
# 2724  {method 'view' of 'torch._C._TensorBase' objects}
# 2725  {method 'zero_' of 'torch._C._TensorBase' obje...
# 2726                   {built-in method _make_subclass}
# 2727  {method '_set_from_file' of 'torch._C.ByteStor...
# 2728                      {built-in method from_buffer}
# 2729  {built-in method torch._C._tracer_warn_use_pyt...
# 2730      {built-in method torch._C._get_tracing_state}
# 2731     {built-in method torch._C._jit_script_compile}
# 2732  {built-in method torch._C.merge_type_from_type...
# 2733      {built-in method torch._C.parse_type_comment}
#
# [2734 rows x 6 columns]

# %% [markdown]
# # Now I need to preprocess the plf column to extract the relevant modules from the text
#
# Do you see text like `{built-in method torch._C._get_tracing_state}`? I can't use that. I need to transform it so I extract the module name and function name from such strings. The template class below is like a cookie cutter. You press it down on a string and the remainder is the module name and function name (two-tuple).

# %%
class Template:
    
    def __init__(self):
        self.special = {
            "\{method '.*' of '.*' objects\}": lambda x: (x.split("'")[3], x.split("'")[1]),
            "\{built-in method .*\}": lambda x: (None, x[1:-1].split()[-1]),
            "\{function (.*)\.(.*) at 0x(\w)*\}": lambda x: (x[1:-1].split()[1].split('.')),
            "<frozen (.*)\.(.*)>:(\d+)\(\w*\)": lambda x: (x.split(':')[0][len('<frozen') + 1:-1], x.split(':')[1].split('(')[1][:-1]),
            "<frozen (.*)\.(.*)>:(\d+)\(<\w*>\)": lambda x: (x.split(':')[0][len('<frozen') + 1:-1], None),
            "\w+\.py:\d+\(\w+\)": lambda x: (None, None),
            "\w+\.py:\d+\(<\w+>\)": lambda x: (None, None),
            "<string>:\d+\(<\w+>\)": lambda x: (None, None),
            "<string>:\d+\(\w+\)": lambda x: (None, None),
            "\{instance\}": lambda x: (None, None),
            "\{((\w)+\.)+\w+\}": lambda x: (x[0:-1], None),
            "<decorator-gen-\d+>:\d+\(<?\w+>?\)": lambda x: (None, None)
        }
    
    def validate(self, df):
        flag = False
        def setf():
            nonlocal flag
            flag = True
            return True
        for line in df['plf']:
            k = toby.match(line)
            not k and '/' != line[0] and setf() and print(line)
        if not flag:
            print("Validation success")
        
    def match(self, t):
        for k in self.special:
            pattern = re.compile(k)
            if pattern.match(t):
                return k
            
    def is_c_extension(self, t):
        k = self.match(t)
        if k is not None:
            m, f = self.special[k](t) # m: module, f: function
            if m is None:
                return False
            ms = m.split('.')
            for i in range(len(ms)):
                candidate_mod_name = '.'.join(ms[:len(ms)-i])
                try:
                    candidate_mod = importlib.import_module(candidate_mod_name)
                except:
                    continue
                try:
                    ans = c_extens.is_c_extension(candidate_mod) # I am trusting a stackoverflow solution
                    if ans is None:
                        ans = False
                    return ans
                except:
                    return False
        return False
        

toby = Template()

# %%
toby.validate(df)
# Out:
# Validation success

# %% [markdown]
# # We see calls to C Extensions below

# %%
c_df = df[df['plf'].map(toby.is_c_extension)]
c_df
# Out:
#       ncalls tottime percallnode cumtime percallgraph  \
# 322        1   0.000       0.000   0.000        0.000
# 762        2   0.000       0.000   0.000        0.000
# 978       13   0.000       0.000   0.000        0.000
# 1160    3000   3.303       0.001   3.303        0.001
# 2691       2   0.000       0.000   0.000        0.000
# 2699  310000   0.091       0.000   0.091        0.000
# 2700   12315   0.004       0.000   0.004        0.000
# 2701  310000   2.161       0.000   2.161        0.000
# 2702     136   0.001       0.000   0.001        0.000
# 2703  310000   0.829       0.000   0.829        0.000
# 2704    6112   0.006       0.000   0.006        0.000
# 2705    6206   0.010       0.000   0.010        0.000
# 2706       5   0.008       0.002   0.008        0.002
# 2707   36000   0.655       0.000   0.655        0.000
# 2708   18000   2.794       0.000   2.794        0.000
# 2709   18000   0.708       0.000   0.708        0.000
# 2710   17994   0.012       0.000   0.012        0.000
# 2711  310000   4.985       0.000   4.985        0.000
# 2712       6   0.000       0.000   0.000        0.000
# 2713    3000   0.076       0.000   0.076        0.000
# 2714   36000   1.269       0.000   1.269        0.000
# 2715    3000   0.004       0.000   0.004        0.000
# 2716       6   0.000       0.000   0.000        0.000
# 2717    3100   0.025       0.000   0.025        0.000
# 2718       4   0.000       0.000   0.000        0.000
# 2719   18000   0.326       0.000   0.326        0.000
# 2720     100   0.001       0.000   0.001        0.000
# 2721    9300   0.064       0.000   0.064        0.000
# 2722  620000   2.007       0.000   2.007        0.000
# 2723       6   0.004       0.001   0.004        0.001
# 2724  310000   1.869       0.000   1.869        0.000
# 2725   17994   0.339       0.000   0.339        0.000
# 2727       2   0.033       0.016   0.033        0.016
#
#                                                     plf
# 322    {method 'disable' of '_lsprof.Profiler' objects}
# 762      {method 'load' of '_pickle.Unpickler' objects}
# 978   {method 'getrandbits' of '_random.Random' obje...
# 1160  {method 'run_backward' of 'torch._C._EngineBas...
# 2691  {method '_set_from_file' of 'torch._C.LongStor...
# 2699  {method 'contiguous' of 'torch._C._TensorBase'...
# 2700   {method 'dim' of 'torch._C._TensorBase' objects}
# 2701  {method 'float' of 'torch._C._TensorBase' obje...
# 2702  {method 'item' of 'torch._C._TensorBase' objects}
# 2703  {method 'numpy' of 'torch._C._TensorBase' obje...
# 2704  {method 'size' of 'torch._C._TensorBase' objects}
# 2705    {method 'to' of 'torch._C._TensorBase' objects}
# 2706  {method 'tolist' of 'torch._C._TensorBase' obj...
# 2707  {method 'add_' of 'torch._C._TensorBase' objects}
# 2708  {method 'addcdiv_' of 'torch._C._TensorBase' o...
# 2709  {method 'addcmul_' of 'torch._C._TensorBase' o...
# 2710  {method 'detach_' of 'torch._C._TensorBase' ob...
# 2711   {method 'div' of 'torch._C._TensorBase' objects}
# 2712  {method 'is_floating_point' of 'torch._C._Tens...
# 2713  {method 'log_softmax' of 'torch._C._TensorBase...
# 2714  {method 'mul_' of 'torch._C._TensorBase' objects}
# 2715  {method 'numel' of 'torch._C._TensorBase' obje...
# 2716  {method 'random_' of 'torch._C._TensorBase' ob...
# 2717  {method 'reshape' of 'torch._C._TensorBase' ob...
# 2718  {method 'set_' of 'torch._C._TensorBase' objects}
# 2719  {method 'sqrt' of 'torch._C._TensorBase' objects}
# 2720   {method 'sum' of 'torch._C._TensorBase' objects}
# 2721     {method 't' of 'torch._C._TensorBase' objects}
# 2722  {method 'transpose' of 'torch._C._TensorBase' ...
# 2723  {method 'uniform_' of 'torch._C._TensorBase' o...
# 2724  {method 'view' of 'torch._C._TensorBase' objects}
# 2725  {method 'zero_' of 'torch._C._TensorBase' obje...
# 2727  {method '_set_from_file' of 'torch._C.ByteStor...

# %% [markdown]
# # Approximately what fraction of time was spent in C code?

# %%
"{0:.3%}".format(c_df['cumtime'].map(float).sum() / df['cumtime'].map(float).max())
# Out:
# '40.297%'
