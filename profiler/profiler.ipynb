# %% [markdown]
# # Is a good portion of an ML execution spent in C code?

# %%
import pstats
import io
import pandas as pd
import numpy as np

import os
import re
import importlib

# The module below implements a function that identifies which modules are C Extensions
import c_extens # thanks https://stackoverflow.com/questions/20339053/in-python-how-can-one-tell-if-a-module-comes-from-a-c-extension

# %% [markdown]
# # The function below turns the binary output of cProfile into a string
# We acquire the binary output of [cProfile](https://docs.python.org/3.7/library/profile.html#module-cProfile) by running:
#
# `python -m cProfile -o output.cprof code_i_want_to_profile.py`

# %%
def get_raw_output(source):
    stream = io.StringIO()
    stats = pstats.Stats(source, stream=stream)
    stats.print_stats()
    raw_output = stream.getvalue().split('\n')
    stream.close()
    return raw_output

# %% [markdown]
# # The function below turns the string output of cProfile into a pandas DF

# %%
def to_df(raw: str) -> pd.DataFrame:
    columns = ['ncalls', 'tottime', 'percall', 'cumtime', 'percall', 'filename:lineno(function)']
    
    # filter non-tabular metadata
    tabular_raw = None
    for i, line in enumerate(raw):
        if line.split() == columns:
            tabular_raw = raw[i:]
            break
    
    # we unique the names of the columns for Pandas
    columns[2] = 'percallnode'
    columns[4] = 'percallgraph'
    
    # we rename for pandas
    columns[5] = 'plf' # p: path, l: lineno, f: function
    
    import re
    tabular = [re.split('\s\s+', line) for line in tabular_raw[1:]]
    
    # preprocess
    for i in range(len(tabular)):
        # filter empty cells
        line = tabular.pop(0)
        line = [word for word in line if word]
        if line:
            # Last cell needs to be unmerged
            last = line.pop()
            split_idx = last.find(' ')
            n, s = last[0:split_idx], last[split_idx+1:]
            line.append(n)
            line.append(s)
            assert len(line) == len(columns), "i: {}, len: {} --- {}".format(i, len(line), line)
            tabular.append(line)
    
    # Ready to load into DF
    df = pd.DataFrame(tabular)
    df.columns = columns
    return df

# %% [markdown]
# # Load the cProfile binary into a pandas DataFrame

# %%
df = to_df(get_raw_output('tf_mnist.cprof'))

# %%
df
# Out:
#       ncalls tottime percallnode cumtime percallgraph  \
# 0       2375   0.001       0.000   0.001        0.000
# 1        124   0.000       0.000   0.000        0.000
# 2        554   0.000       0.000   0.000        0.000
# 3          1   0.000       0.000   0.000        0.000
# 4          2   0.000       0.000   0.000        0.000
# 5          1   0.000       0.000   0.000        0.000
# 6          1   0.000       0.000   0.000        0.000
# 7          4   0.000       0.000   0.000        0.000
# 8        740   0.000       0.000   0.000        0.000
# 9       2987   0.001       0.000   0.001        0.000
# 10       227   0.000       0.000   0.000        0.000
# 11        89   0.000       0.000   0.000        0.000
# 12       129   0.000       0.000   0.000        0.000
# 13         2   0.000       0.000   0.000        0.000
# 14        81   0.000       0.000   0.000        0.000
# 15         1   0.000       0.000   0.000        0.000
# 16         2   0.000       0.000   0.000        0.000
# 17    340031   0.046       0.000   0.046        0.000
# 18     19237   0.010       0.000   0.010        0.000
# 19      2740   0.001       0.000   0.002        0.000
# 20    100600   0.022       0.000   0.022        0.000
# 21       108   0.000       0.000   0.000        0.000
# 22        82   0.000       0.000   0.000        0.000
# 23        18   0.000       0.000   0.000        0.000
# 24      2831   0.000       0.000   0.000        0.000
# 25        62   0.000       0.000   0.000        0.000
# 26        29   0.000       0.000   0.000        0.000
# 27      6008   0.002       0.000   0.002        0.000
# 28         1   0.000       0.000   0.000        0.000
# 29    146410   0.035       0.000   0.036        0.000
# ...      ...     ...         ...     ...          ...
# 9181       2   0.000       0.000   0.000        0.000
# 9182       2   0.000       0.000   0.008        0.004
# 9183       1   0.000       0.000   0.008        0.008
# 9184       2   0.000       0.000   0.025        0.012
# 9185       2   0.000       0.000   0.025        0.012
# 9186       2   0.000       0.000   0.028        0.014
# 9187       2   0.000       0.000   0.000        0.000
# 9188       3   0.000       0.000   0.000        0.000
# 9189       1   0.000       0.000   0.002        0.002
# 9190       2   0.000       0.000   0.003        0.001
# 9191       1   0.000       0.000   0.000        0.000
# 9192       3   0.000       0.000   0.000        0.000
# 9193       3   0.000       0.000   0.000        0.000
# 9194       1   0.000       0.000   0.000        0.000
# 9195       2   0.000       0.000   0.000        0.000
# 9196       2   0.000       0.000   0.000        0.000
# 9197       6   0.000       0.000   0.000        0.000
# 9198       2   0.000       0.000   0.000        0.000
# 9199       4   0.000       0.000   0.003        0.001
# 9200       2   0.000       0.000   0.002        0.001
# 9201       2   0.000       0.000   0.002        0.001
# 9202       3   0.000       0.000   0.000        0.000
# 9203       2   0.000       0.000   0.000        0.000
# 9204       1   0.000       0.000   0.000        0.000
# 9205       1   0.000       0.000   0.000        0.000
# 9206       2   0.000       0.000   0.000        0.000
# 9207       2   0.000       0.000   0.000        0.000
# 9208       9   0.000       0.000   0.008        0.001
# 9209       1   0.000       0.000   0.000        0.000
# 9210       1   0.000       0.000   0.000        0.000
#
#                                                     plf
# 0                {method 'find' of 'bytearray' objects}
# 1           {method 'translate' of 'bytearray' objects}
# 2                  {method 'decode' of 'bytes' objects}
# 3                    {method 'join' of 'bytes' objects}
# 4                           {built-in method maketrans}
# 5                   {method 'rfind' of 'bytes' objects}
# 6                  {method 'rstrip' of 'bytes' objects}
# 7              {method 'startswith' of 'bytes' objects}
# 8              {method 'get' of 'mappingproxy' objects}
# 9           {method 'values' of 'mappingproxy' objects}
# 10           {method 'items' of 'mappingproxy' objects}
# 11            {method 'copy' of 'mappingproxy' objects}
# 12              {method 'setter' of 'property' objects}
# 13             {method 'deleter' of 'property' objects}
# 14              {method 'throw' of 'generator' objects}
# 15                            {built-in method fromhex}
# 16                    {method 'copy' of 'list' objects}
# 17                  {method 'append' of 'list' objects}
# 18                  {method 'insert' of 'list' objects}
# 19                  {method 'extend' of 'list' objects}
# 20                     {method 'pop' of 'list' objects}
# 21                  {method 'remove' of 'list' objects}
# 22                   {method 'index' of 'list' objects}
# 23                   {method 'count' of 'list' objects}
# 24                 {method 'reverse' of 'list' objects}
# 25                    {method 'sort' of 'list' objects}
# 26               {method 'bit_length' of 'int' objects}
# 27                         {built-in method from_bytes}
# 28      {function _typedict.__getitem__ at 0x108cf3158}
# 29                     {method 'get' of 'dict' objects}
# ...                                                 ...
# 9181  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9182  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9183  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9184  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9185  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9186  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9187  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9188  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9189  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9190  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9191  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9192  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9193  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9194  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9195  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9196  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9197  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9198  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9199  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9200  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9201  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9202  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9203  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9204  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9205  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9206  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9207  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9208  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9209  /anaconda3/lib/python3.7/site-packages/tensorf...
# 9210  /anaconda3/lib/python3.7/site-packages/tensorf...
#
# [9211 rows x 6 columns]

# %% [markdown]
# # Now I need to preprocess the plf column to extract the relevant modules from the text
#
# Do you see text like `{built-in method torch._C._get_tracing_state}`? I can't use that. I need to transform it so I extract the module name and function name from such strings. The template class below is like a cookie cutter. You press it down on a string and the remainder is the module name and function name (two-tuple).

# %%
class Template:
    
    def __init__(self):
        self.special = {
            "\{method '.*' of '.*' objects\}": lambda x: (x.split("'")[3], x.split("'")[1]),
            "\{built-in method .*\}": lambda x: (None, x[1:-1].split()[-1]),
            "\{function (.*)\.(.*) at 0x(\w)*\}": lambda x: (x[1:-1].split()[1].split('.')),
            "<frozen (.*)\.(.*)>:(\d+)\(\w*\)": lambda x: (x.split(':')[0][len('<frozen') + 1:-1], x.split(':')[1].split('(')[1][:-1]),
            "<frozen (.*)\.(.*)>:(\d+)\(<\w*>\)": lambda x: (x.split(':')[0][len('<frozen') + 1:-1], None),
            "\w+\.py:\d+\(\w+\)": lambda x: (None, None),
            "\w+\.py:\d+\(<\w+>\)": lambda x: (None, None),
            "<string>:\d+\(<\w+>\)": lambda x: (None, None),
            "<string>:\d+\(\w+\)": lambda x: (None, None),
            "\{instance\}": lambda x: (None, None),
            "\{((\w)+\.)+\w+\}": lambda x: (x[0:-1], None),
            "<decorator-gen-\d+>:\d+\(<?\w+>?\)": lambda x: (None, None)
        }
    
    def validate(self, df):
        flag = False
        def setf():
            nonlocal flag
            flag = True
            return True
        for line in df['plf']:
            k = toby.match(line)
            not k and '/' != line[0] and setf() and print(line)
        if not flag:
            print("Validation success")
        
    def match(self, t):
        for k in self.special:
            pattern = re.compile(k)
            if pattern.match(t):
                return k
            
    def is_c_extension(self, t):
        k = self.match(t)
        if k is not None:
            m, f = self.special[k](t) # m: module, f: function
            if m is None:
                return False
            ms = m.split('.')
            for i in range(len(ms)):
                candidate_mod_name = '.'.join(ms[:len(ms)-i])
                try:
                    candidate_mod = importlib.import_module(candidate_mod_name)
                except:
                    continue
                try:
                    ans = c_extens.is_c_extension(candidate_mod) # I am trusting a stackoverflow solution
                    if ans is None:
                        ans = False
                    return ans
                except:
                    return False
        return False
        

toby = Template()

# %%
toby.validate(df)
# Out:
# Validation success

# %% [markdown]
# # We see calls to C Extensions below

# %%
c_df = df[df['plf'].map(toby.is_c_extension)]
c_df
# Out:
# /anaconda3/lib/python3.7/site-packages/pydot.py:18: UserWarning: Couldn't import dot_parser, loading of dot files will not be possible.
#   "Couldn't import dot_parser, "
#      ncalls tottime percallnode cumtime percallgraph  \
# 467       1   0.000       0.000   0.000        0.000
# 805      10   0.000       0.000   0.000        0.000
# 1194    220   0.123       0.001   0.123        0.001
# 1195      4   0.000       0.000   0.000        0.000
# 1230      5   0.005       0.001   0.006        0.001
# 1426    176   0.014       0.000   0.014        0.000
# 1427      1   0.000       0.000   0.000        0.000
# 1429     18   0.000       0.000   0.000        0.000
# 1874      1   0.000       0.000   0.000        0.000
# 1902      1   0.000       0.000   0.000        0.000
# 2497     90   0.009       0.000   0.009        0.000
# 2498     90   0.000       0.000   0.000        0.000
# 2499    467   0.000       0.000   0.000        0.000
# 2500     49   0.000       0.000   0.000        0.000
# 2501    467   0.000       0.000   0.000        0.000
# 2502   1845   0.002       0.000   0.002        0.000
# 2503     49   0.000       0.000   0.000        0.000
# 2504     24   0.000       0.000   0.000        0.000
# 2505     21   0.000       0.000   0.000        0.000
# 2506   1246   0.005       0.000   0.005        0.000
# 2507   1268   0.002       0.000   0.002        0.000
# 2509   1430   0.001       0.000   0.001        0.000
# 2510      2   0.000       0.000   0.000        0.000
# 2511   1611   0.015       0.000   0.015        0.000
# 2512   1235   0.004       0.000   0.004        0.000
# 2513     19   0.000       0.000   0.000        0.000
# 2514    477   0.000       0.000   0.000        0.000
# 2516      5   0.000       0.000   0.000        0.000
# 2517     11   0.000       0.000   0.000        0.000
# 2518     12   0.000       0.000   0.000        0.000
# 2519     11   0.000       0.000   0.000        0.000
#
#                                                     plf
# 467    {method 'disable' of '_lsprof.Profiler' objects}
# 805   {method 'from_buffer' of '_ctypes.PyCArrayType...
# 1194  {method 'decompress' of 'zlib.Decompress' obje...
# 1195      {method 'flush' of 'zlib.Decompress' objects}
# 1230  {method 'shuffle' of 'mtrand.RandomState' obje...
# 1426       {method 'update' of '_hashlib.HASH' objects}
# 1427    {method 'hexdigest' of '_hashlib.HASH' objects}
# 1429  {method 'getrandbits' of '_random.Random' obje...
# 1874  {method 'ParseFile' of 'pyexpat.xmlparser' obj...
# 1902        {method 'bind' of '_socket.socket' objects}
# 2497  {method 'AddSerializedFile' of 'google.protobu...
# 2498  {method 'AddFileDescriptor' of 'google.protobu...
# 2499  {method 'AddDescriptor' of 'google.protobuf.py...
# 2500  {method 'AddEnumDescriptor' of 'google.protobu...
# 2501  {method 'FindMessageTypeByName' of 'google.pro...
# 2502  {method 'FindFieldByName' of 'google.protobuf....
# 2503  {method 'FindEnumTypeByName' of 'google.protob...
# 2504  {method 'FindOneofByName' of 'google.protobuf....
# 2505  {method 'get' of 'google.protobuf.pyext._messa...
# 2506  {method 'ByteSize' of 'google.protobuf.pyext._...
# 2507  {method 'CopyFrom' of 'google.protobuf.pyext._...
# 2509  {method 'HasField' of 'google.protobuf.pyext._...
# 2510  {method 'MergeFrom' of 'google.protobuf.pyext....
# 2511  {method 'ParseFromString' of 'google.protobuf....
# 2512  {method 'SerializeToString' of 'google.protobu...
# 2513  {method 'SetInParent' of 'google.protobuf.pyex...
# 2514  {method 'WhichOneof' of 'google.protobuf.pyext...
# 2516  {method 'add' of 'google.protobuf.pyext._messa...
# 2517  {method 'extend' of 'google.protobuf.pyext._me...
# 2518  {method 'append' of 'google.protobuf.pyext._me...
# 2519  {method 'extend' of 'google.protobuf.pyext._me...

# %% [markdown]
# # Approximately what fraction of time was spent in C code?

# %%
"{0:.3%}".format(c_df['cumtime'].map(float).sum() / df['cumtime'].map(float).max())
# Out:
# '0.611%'
